# %% [markdown]
# # Part 1

# %% [markdown]
# # 1) Introduction/Business Problem

# %% [markdown]
# ### The idea of this study is to help people planning to open a new vegetarian restaurant in New York. We will look at the cuisines to find the best cuisines to include and to choose the right location, we will look at areas where vegetarian restaurants are established.
#
# where should I open it in NY?\
# which dishes or cuisines are popular that should be included?

# %% [markdown]
# ## 2) Data section

# %% [markdown]
# ### To provide the necessary information I'll be combining a list of over 18,000 restaurants in the US that serve vegetarian or vegan food provided by Datafiniti's Business Database. The dataset includes address, city, state, business name, business categories, menu data, phone numbers, and Foursquare API to collect competitors on the same neighborhoods.
#
# Datafiniti's Business Database on vegetarian or vegan food  is publicly available at this website: https://www.kaggle.com/datafiniti/vegetarian-vegan-restaurants?select=Datafiniti_Vegetarian_and_Vegan_Restaurants.csv
